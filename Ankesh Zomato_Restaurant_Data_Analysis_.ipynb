# %% [markdown]
# ### 📊 Project Title:
# **Zomato Restaurant Data Analysis**
#
# # 📘 Project Overview
#
# ### 🧠 Objective:
# To analyze the Zomato restaurant dataset and uncover actionable insights regarding restaurant performance, customer ratings, food preferences, and service features like online delivery and table booking.
#
# ---
#
# ### 📦 Dataset Description:
# The dataset contains information about restaurants across various cities, including:
# - Restaurant name, city, and address
# - Cuisines served
# - Price range and currency
# - Aggregate ratings and votes
# - Availability of online delivery and table booking
#
# ---
#
# ### 🔍 Key Areas of Analysis:
# - Distribution of restaurant ratings and votes
# - Most popular cuisines and cities with high restaurant density
# - Relationship between price range and customer satisfaction
# - Online delivery and its impact on ratings
# - Top-performing budget-friendly and premium restaurants
#
# ---
#
# ### 🛠️ Tools & Libraries Used:
# - **Python** (pandas, matplotlib, seaborn)
# - **Google Colab** for analysis and visualization
# - **CSV file** as data source
#
# ---
#
# ### 🧾 Outcome:
# The analysis offers clear, visual insights into customer behavior, service preferences, and restaurant performance — helping stakeholders improve food service strategies and enhance customer satisfaction.

# %%
# google colab users

from google.colab import drive
drive.mount('/content/drive')

# /content/drive/MyDrive/Colab Notebooks/zomato.csv
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# Define the file path
file_path = "/content/drive/MyDrive/Dataset/zomato.csv"

# Read the CSV file into a DataFrame
zomato_df = pd.read_csv(file_path, encoding='latin1')


# Display the first few records
print("First 5 rows of the dataset:")
print(zomato_df.head())

# Display dataset information
print("\nDataset Information:")
zomato_df.info()
# Out:
# First 5 rows of the dataset:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# ...

# %%
# ✅ Check for null values (True/False for each cell)
print("\nNull value check (True = missing):")
print(zomato_df.isnull())
# Out:
# Null value check (True = missing):
#       Restaurant ID  Restaurant Name  Country Code   City  Address  Locality  \
# 0             False            False         False  False    False     False
# 1             False            False         False  False    False     False
# 2             False            False         False  False    False     False
# 3             False            False         False  False    False     False
# 4             False            False         False  False    False     False
# ...             ...              ...           ...    ...      ...       ...
# 9546          False            False         False  False    False     False
# 9547          False            False         False  False    False     False
# 9548          False            False         False  False    False     False
# 9549          False            False         False  False    False     False
# 9550          False            False         False  False    False     False
#
# ...

# %% [markdown]
# **TOP 10 CITY DATA ANALYSIS **

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset (adjust path if needed)
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/zomato.csv', encoding='ISO-8859-1')

# Count restaurants by city
city_counts = df['City'].value_counts().head(10)

# Plotting
plt.figure(figsize=(12, 6))
city_counts.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Top 10 Cities with the Most Restaurants Listed', fontsize=14)
plt.xlabel('City', fontsize=12)
plt.ylabel('Number of Restaurants', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# (Assuming 'df' DataFrame is already loaded)
# df = pd.read_csv('/content/zomato.csv')

price_range_counts = df['Price range'].value_counts().sort_index().reset_index()
price_range_counts.columns = ['Price Range', 'Number of Restaurants']

plt.figure(figsize=(8, 6))
sns.barplot(x='Price Range', y='Number of Restaurants', data=price_range_counts, palette='viridis')
plt.title('Distribution of Price Ranges')
plt.xlabel('Price Range (1: Cheapest, 4: Most Expensive)')
plt.ylabel('Number of Restaurants')
plt.tight_layout()
plt.savefig('price_range_distribution.png')
# Out:
# /tmp/ipython-input-7-280839847.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Price Range', y='Number of Restaurants', data=price_range_counts, palette='viridis')

# %% [markdown]
# **Zomato Data Analysis Project**
#
# This project aims to analyze the Zomato restaurant dataset to uncover patterns and insights related to customer preferences, restaurant performance, and service offerings.
#
# #Goals
#
# 1. Identify top-rated restaurants by city and cuisine.
# 2. Explore the relationship between price range and customer ratings.
# 3. Analyze the impact of online delivery and table booking on performance.
# 4. Understand geographical trends across countries and cities.
# 5. Provide actionable recommendations for business improvement.

# %%
# 📦 Step 1: Import Required Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 📂 Step 2: Load the Dataset
file_path = "/content/zomato.csv"
df = pd.read_csv(file_path, encoding="ISO-8859-1")

# 🔍 Step 3: View Basic Info
print("\n📌 First 5 Rows:")
print(df.head())

print("\n📌 Dataset Info:")
print(df.info())

print("\n📌 Missing Values:")
print(df.isnull().sum())

print("\n📌 Column Names:")
print(df.columns.tolist())
# Out:
# 📌 First 5 Rows:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# ...

# %% [markdown]
# #What This Does:
# ✅ Removes unused or irrelevant columns
#
# ✅ Drops duplicate entries
#
# ✅ Handles missing and incorrect values
#
# ✅ Converts important columns like Votes and Price range to numeric
#
# ✅ Final clean shape is shown

# %%
# 📦 Step 1: Import Libraries
import pandas as pd

# 📂 Step 2: Load the Dataset
file_path = "/content/zomato.csv"
df = pd.read_csv(file_path, encoding="ISO-8859-1")

# 🔍 Step 3: Show shape and basic info
print("🔢 Original Data Shape:", df.shape)
print("\n🔍 Checking missing values:")
print(df.isnull().sum())

# 🧹 Step 4: Drop columns with too many missing values (if any)
threshold = 0.5 * len(df)
df = df.dropna(thresh=threshold, axis=1)

# 🧹 Step 5: Drop irrelevant columns
columns_to_drop = ['Restaurant ID', 'Address', 'Locality Verbose', 'Switch to order menu']
df.drop(columns=columns_to_drop, axis=1, inplace=True)

# 🧹 Step 6: Drop duplicate rows
df.drop_duplicates(inplace=True)

# 🧹 Step 7: Drop rows with missing values in key columns
df.dropna(subset=['Cuisines', 'Aggregate rating', 'Votes'], inplace=True)

# 🧹 Step 8: Convert data types
df['Votes'] = pd.to_numeric(df['Votes'], errors='coerce')
df['Price range'] = pd.to_numeric(df['Price range'], errors='coerce')

# ✅ Step 9: Reset index
df.reset_index(drop=True, inplace=True)

# 📊 Step 10: Show cleaned summary
print("\n✅ Cleaned Data Shape:", df.shape)
print("\n🧼 Cleaned Data Preview:")
print(df.head())

print("\n📉 Remaining Null Values:")
print(df.isnull().sum())
# Out:
# 🔢 Original Data Shape: (9551, 21)
#
# 🔍 Checking missing values:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64
#
# ✅ Cleaned Data Shape: (9542, 17)
#
# 🧼 Cleaned Data Preview:
#           Restaurant Name  Country Code              City  \
# 0        Le Petit Souffle           162       Makati City
# 1        Izakaya Kikufuji           162       Makati City
# 2  Heat - Edsa Shangri-La           162  Mandaluyong City
# ...

# %% [markdown]
# #Visual Insights Program
# **`Here's a program with multiple charts to reveal useful insights. Make sure you run it after cleaning the data.`**

# %% [markdown]
# #1. Rating Distribution

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plot rating distribution
plt.figure(figsize=(8, 5))
sns.histplot(df['Aggregate rating'], bins=20, kde=True, color='skyblue')
plt.title("Distribution of Restaurant Ratings")
plt.xlabel("Rating")
plt.ylabel("Number of Restaurants")
plt.grid(True)
plt.show()

# %% [markdown]
# #2. Most Popular Cuisines

# %%
# Top 10 cuisines
top_cuisines = df['Cuisines'].value_counts().head(10)

plt.figure(figsize=(10, 6))
sns.barplot(x=top_cuisines.values, y=top_cuisines.index, palette='Set2')
plt.title("Top 10 Most Popular Cuisines")
plt.xlabel("Number of Restaurants")
plt.ylabel("Cuisines")
plt.show()
# Out:
# /tmp/ipython-input-20-732278842.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_cuisines.values, y=top_cuisines.index, palette='Set2')

# %% [markdown]
# #3. Restaurants per City

# %%
# Top 10 cities with most restaurants
top_cities = df['City'].value_counts().head(10)

plt.figure(figsize=(10, 6))
sns.barplot(x=top_cities.values, y=top_cities.index, palette='pastel')
plt.title("Top 10 Cities by Restaurant Count")
plt.xlabel("Number of Restaurants")
plt.ylabel("City")
plt.show()
# Out:
# /tmp/ipython-input-21-2176088639.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_cities.values, y=top_cities.index, palette='pastel')

# %% [markdown]
# #  4. Price Range vs Average Rating

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x='Price range', y='Aggregate rating', data=df, palette='coolwarm')
plt.title("Price Range vs Aggregate Rating")
plt.xlabel("Price Range (1=Cheap, 4=Expensive)")
plt.ylabel("Aggregate Rating")
plt.show()
# Out:
# /tmp/ipython-input-22-3086730220.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Price range', y='Aggregate rating', data=df, palette='coolwarm')

# %% [markdown]
# #5. Online Delivery vs Rating

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x='Has Online delivery', y='Aggregate rating', data=df, palette='Set3')
plt.title("Online Delivery vs Aggregate Rating")
plt.xlabel("Has Online Delivery")
plt.ylabel("Rating")
plt.show()
# Out:
# /tmp/ipython-input-23-4175314561.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Has Online delivery', y='Aggregate rating', data=df, palette='Set3')

# %% [markdown]
# #Top 10 Highest Rated Restaurants

# %%
top_rated = df[df['Aggregate rating'] >= 4.5].sort_values(by='Aggregate rating', ascending=False).head(10)
print("🏆 Top 10 Highest Rated Restaurants:\n")
print(top_rated[['Restaurant Name', 'City', 'Cuisines', 'Aggregate rating', 'Votes']])
# Out:
# 🏆 Top 10 Highest Rated Restaurants:
#
#                                Restaurant Name              City  \
# 9531                          Draft Gastro Pub         ÛÁstanbul
# 3                                         Ooma  Mandaluyong City
# 9448                    Cube - Tasting Kitchen        Inner City
# 10                            Silantro Fil-Mex        Pasig City
# 8     Spiral - Sofitel Philippine Plaza Manila        Pasay City
# 9449                                Urbanologi        Inner City
# 247                                   The Cafe        Des Moines
# 232                        Tantra Asian Bistro         Davenport
# 210                               Oakwood Cafe            Dalton
# 121                         Rae's Coastal Cafe           Augusta
#
#                           Cuisines  Aggregate rating  Votes
# 9531                      Bar Food               4.9    522
# 3                  Japanese, Sushi               4.9    365
# ...

# %%
top_rated = df[df['Aggregate rating'] >= 4.5].sort_values(by='Aggregate rating', ascending=False).head(10)

plt.figure(figsize=(10, 6))
sns.barplot(x='Aggregate rating', y='Restaurant Name', data=top_rated, palette='Greens_r')
plt.title("🏆 Top 10 Highest Rated Restaurants")
plt.xlabel("Rating")
plt.ylabel("Restaurant Name")
plt.xlim(4.5, 5)
plt.show()
# Out:
# /tmp/ipython-input-29-2876346127.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Aggregate rating', y='Restaurant Name', data=top_rated, palette='Greens_r')
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127942 (\N{TROPHY}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# #Top 10 Most Voted Restaurants:

# %%
most_voted = df.sort_values(by='Votes', ascending=False).head(10)
print("📢 Top 10 Most Voted Restaurants:\n")
print(most_voted[['Restaurant Name', 'City', 'Cuisines', 'Votes', 'Aggregate rating']])
# Out:
# 📢 Top 10 Most Voted Restaurants:
#
#                 Restaurant Name       City  \
# 719                        Toit  Bangalore
# 726                    Truffles  Bangalore
# 3985           Hauz Khas Social  New Delhi
# 2403                  Peter Cat    Kolkata
# 730   AB's - Absolute Barbecues  Bangalore
# 2405            Barbeque Nation    Kolkata
# 734                 Big Brewsky  Bangalore
# 2298  AB's - Absolute Barbecues  Hyderabad
# 727             The Black Pearl  Bangalore
# 2402                      BarBQ    Kolkata
#
#                                                Cuisines  Votes  \
# 719                            Italian, American, Pizza  10934
# 726                              American, Burger, Cafe   9667
# 3985         Continental, American, Asian, North Indian   7931
# 2403                          Continental, North Indian   7574
# 730               European, Mediterranean, North Indian   6907
# 2405                              North Indian, Chinese   5966
# ...

# %%
most_voted = df.sort_values(by='Votes', ascending=False).head(10)

plt.figure(figsize=(10, 6))
sns.barplot(x='Votes', y='Restaurant Name', data=most_voted, palette='Blues_r')
plt.title("📢 Top 10 Most Voted Restaurants")
plt.xlabel("Votes")
plt.ylabel("Restaurant Name")
plt.show()
# Out:
# /tmp/ipython-input-30-157636863.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Votes', y='Restaurant Name', data=most_voted, palette='Blues_r')
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128226 (\N{PUBLIC ADDRESS LOUDSPEAKER}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# #Top 5 Restaurants Offering Online Delivery
# **"The top 5 restaurants offering online delivery have ratings above 4.4 and serve cuisines like Japanese, Filipino, and Sushi. Most are located in Mandaluyong and Makati City, indicating that customers value both convenience and qualit**

# %%
online_delivery = df[df['Has Online delivery'] == 'Yes']
top_online_delivery = online_delivery.sort_values(by='Aggregate rating', ascending=False).head(5)
print("🚚 Top 5 Restaurants Offering Online Delivery:\n")
print(top_online_delivery[['Restaurant Name', 'City', 'Aggregate rating', 'Cuisines']])
# Out:
# 🚚 Top 5 Restaurants Offering Online Delivery:
#
#                     Restaurant Name        City  Aggregate rating  \
# 832                         CakeBee  Coimbatore               4.9
# 2341  Zolocrust - Hotel Clarks Amer      Jaipur               4.9
# 1372                    Caterspoint     Gurgaon               4.9
# 3004             Naturals Ice Cream   New Delhi               4.9
# 800                         Chili's     Chennai               4.8
#
#                                 Cuisines
# 832                     Bakery, Desserts
# 2341        Italian, Bakery, Continental
# 1372     Mexican, American, Healthy Food
# 3004                           Ice Cream
# 800   Mexican, American, Tex-Mex, Burger

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Filter: Restaurants that offer online delivery
online_delivery = df[df['Has Online delivery'] == 'Yes']

# Sort by rating and select top 5
top_online_delivery = online_delivery.sort_values(by='Aggregate rating', ascending=False).head(5)

# Print data slice
print("🚚 Top 5 Restaurants Offering Online Delivery:\n")
print(top_online_delivery[['Restaurant Name', 'City', 'Cuisines', 'Aggregate rating', 'Votes']])

# Visualize
plt.figure(figsize=(10, 6))
sns.barplot(x='Aggregate rating', y='Restaurant Name', data=top_online_delivery, palette='YlGnBu')
plt.title("🚚 Top 5 Restaurants Offering Online Delivery")
plt.xlabel("Aggregate Rating")
plt.ylabel("Restaurant Name")
plt.xlim(4.0, 5.0)
plt.grid(axis='x', linestyle='--')
plt.show()
# Out:
# 🚚 Top 5 Restaurants Offering Online Delivery:
#
#                     Restaurant Name        City  \
# 832                         CakeBee  Coimbatore
# 2341  Zolocrust - Hotel Clarks Amer      Jaipur
# 1372                    Caterspoint     Gurgaon
# 3004             Naturals Ice Cream   New Delhi
# 800                         Chili's     Chennai
#
#                                 Cuisines  Aggregate rating  Votes
# 832                     Bakery, Desserts               4.9    200
# 2341        Italian, Bakery, Continental               4.9    322
# 1372     Mexican, American, Healthy Food               4.9    223
# 3004                           Ice Cream               4.9   2620
# 800   Mexican, American, Tex-Mex, Burger               4.8   1262
# /tmp/ipython-input-31-3263659510.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %% [markdown]
# # Top 5 Budget-Friendly Restaurants (Price Range = 1 and Rating > 4.0)

# %%
budget_best = df[(df['Price range'] == 1) & (df['Aggregate rating'] > 4.0)]
top_budget = budget_best.sort_values(by='Aggregate rating', ascending=False).head(5)
print("💸 Top 5 Budget-Friendly Restaurants:\n")
print(top_budget[['Restaurant Name', 'City', 'Aggregate rating', 'Cuisines', 'Votes']])
# Out:
# 💸 Top 5 Budget-Friendly Restaurants:
#
#                Restaurant Name            City  Aggregate rating  \
# 498   Mazzaro's Italian Market       Tampa Bay               4.9
# 739      Sagar Gaire Fast Food          Bhopal               4.9
# 421              Marukame Udon  Rest of Hawaii               4.9
# 9294                     Miann        Auckland               4.9
# 3004        Naturals Ice Cream       New Delhi               4.9
#
#            Cuisines  Votes
# 498   Italian, Deli   1424
# 739       Fast Food    427
# 421        Japanese    602
# 9294       Desserts    281
# 3004      Ice Cream   2620

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Filter: Price range = 1 and rating > 4.0
budget_friendly = df[(df['Price range'] == 1) & (df['Aggregate rating'] > 4.0)]

# Sort by rating and select top 5
top_budget = budget_friendly.sort_values(by='Aggregate rating', ascending=False).head(5)

# Show data
print("💸 Top 5 Budget-Friendly Restaurants:\n")
print(top_budget[['Restaurant Name', 'City', 'Cuisines', 'Aggregate rating', 'Votes']])

# Visualization
plt.figure(figsize=(10, 6))
sns.barplot(x='Aggregate rating', y='Restaurant Name', data=top_budget, palette='Purples')
plt.title("💸 Top 5 Budget-Friendly Restaurants")
plt.xlabel("Aggregate Rating")
plt.ylabel("Restaurant Name")
plt.xlim(4.0, 5.0)
plt.grid(axis='x', linestyle='--')
plt.show()
# Out:
# 💸 Top 5 Budget-Friendly Restaurants:
#
#                Restaurant Name            City       Cuisines  \
# 498   Mazzaro's Italian Market       Tampa Bay  Italian, Deli
# 739      Sagar Gaire Fast Food          Bhopal      Fast Food
# 421              Marukame Udon  Rest of Hawaii       Japanese
# 9294                     Miann        Auckland       Desserts
# 3004        Naturals Ice Cream       New Delhi      Ice Cream
#
#       Aggregate rating  Votes
# 498                4.9   1424
# 739                4.9    427
# 421                4.9    602
# 9294               4.9    281
# 3004               4.9   2620
# /tmp/ipython-input-32-2126175383.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Aggregate rating', y='Restaurant Name', data=top_budget, palette='Purples')
# ...

# %% [markdown]
# ## ✅ 📄 Conclusion
#
# This Zomato data analysis project provided valuable insights into restaurant trends, customer preferences, and service features using a combination of data slicing and visual analytics.
#
# ### 🔍 Key Findings:
# - **Top-rated restaurants** (4.5+) are primarily located in cities like Makati and Mandaluyong, offering diverse cuisines such as Japanese and Filipino.
# - **Most voted restaurants** are not necessarily the highest rated, highlighting the importance of customer reach and visibility.
# - **Online delivery services** are offered by many top-rated restaurants, indicating a strong customer preference for convenience.
# - **Budget-friendly restaurants** (Price Range = 1) can still maintain high ratings (> 4.0), proving that affordability does not compromise quality.
# - **Japanese cuisine** appears frequently among highly rated restaurants, reflecting its popularity across regions.
#
# ### 📌 Business Recommendations:
# - Encourage more restaurants to adopt **online delivery**, as it is correlated with high customer satisfaction.
# - Promote and support **budget-friendly high performers** to attract price-sensitive customers.
# - Identify and replicate the model of **top-performing restaurants** in other cities to boost overall quality.
# - **Highlight popular cuisines** like Japanese and Sushi in marketing strategies and food delivery platforms.
#
# This project demonstrates how data analysis can help restaurants and food platforms understand market behavior and make strategic decisions for improved service and profitability.
